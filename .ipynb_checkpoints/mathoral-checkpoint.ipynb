# %% [markdown]
# # Grand Oral de Mathematique:

# %% [markdown]
# <pre><b>Comment évaluer l'efficacité d'un algorithme ?</b></pre><pre><b>Introduction:</b><pre>Plusieurs algorithmes nous permettent d'effectuer le meme traitement de l'information; neanmoins certains sont plus efficaces que d'autres suivant la quantite de donnees a traiter.</pre></pre><pre><b>Etude de cas:</b><pre>Nous cherchons à verifier la présence d'un nom dans une liste de noms.<br>Nous considérons deux algorithmes similaires: <ul><li>Algo 1: recherche linéaire</li><li>Algo 2: recherche binaire avec pretraitement(tri)</li></ul></pre></pre>

# %% [markdown]
# # algorithme 1: Recherche Linéaire

# %%
def algo1(array, value):
    for element in array:
        if element == value:
            return True
        else:
            continue
    return False

# %% [markdown]
# # algorithme 2: Recherche Binaire avec Pretraitement

# %%
def algo2(array,value):

    def quickSort(arr):
        """Sort arr by using quicksort."""
        less = []
        equal = []
        greater = []

        if len(arr) > 1:
            pivot = arr[0]
            for x in arr:
                if x < pivot:
                    less.append(x)
                elif x == pivot:
                    equal.append(x)
                elif x > pivot:
                    greater.append(x)
            return quickSort(less)+equal+quickSort(greater)
        else:
            return arr

    def binary_search(arr, val):
        "Search val through a sorted arr"
        low = 0
        high = len(arr) - 1
        mid = 0

        while low <= high:

            mid = (high + low) // 2

            if arr[mid] < val:
                low = mid + 1

            elif arr[mid] > val:
                high = mid - 1

            else:
                return True

        return False

    return binary_search(quickSort(array), value)

# %% [markdown]
# Les deux algorithmes effectuent le meme travail (test ci-dessous)

# %%
liste_de_noms = ["jamy","fred","sabine","marcel"]
nom_a_chercher = "sabine"
print(algo1(liste_de_noms, nom_a_chercher))
print(algo2(liste_de_noms, nom_a_chercher))
# Out:
# True
# True

# %% [markdown]
# Utilisons une liste contenant 164457 prénoms:

# %%
with open("prenoms.txt","r",encoding="utf8") as d:
    data = d.readlines()
    for i,line in enumerate(data):
        data[i]=line[:-1]

surname = "sabine"

# %% [markdown]
# <b>Test algorithme 1: recherche linéaire</b><br>Chronometrons le temps d'execution de cette algorithme sur la liste de 164457 prénoms:

# %%
from numpy import float64
from time import perf_counter as now
time_start = float64(now())

print(algo1(data, surname))

time_end = float64(now())
execution_time = time_end - time_start
print(execution_time)
# Out:
# True
# 0.0030481999999993903

# %% [markdown]
# <b>Test algorithme 2: Recherche avec pretraitement</b><br>Pour l'algorithme 2, nous nous permettrons de decomposer la fonction en 2 parties:<br><ol><li>Pretraitement (tri effectué avant l'operation de recherche - effectué en periodes de maintenance)</li><li>Recherche Binaire</li></ol>Nous ne chronometrons que la partie de Recherche (car la partie de pretraitement ne s'effectue qu'une seule fois)

# %% [markdown]
# <b>Pretraitement:</b>

# %%
def quickSort(arr):
    """Sort arr by using quicksort."""
    less = []
    equal = []
    greater = []

    if len(arr) > 1:
        pivot = arr[0]
        for x in arr:
            if x < pivot:
                less.append(x)
            elif x == pivot:
                equal.append(x)
            elif x > pivot:
                greater.append(x)
        return quickSort(less)+equal+quickSort(greater)
    else:
        return arr

# %% [markdown]
# <b>Recherche Binaire:</b>

# %%
def binary_search(arr, val):
    "Search val through a sorted arr"
    low = 0
    high = len(arr) - 1
    mid = 0

    while low <= high:

        mid = (high + low) // 2

        if arr[mid] < val:
            low = mid + 1

        elif arr[mid] > val:
            high = mid - 1

        else:
            return True

    return False

# %% [markdown]
# <b>Test Algorithme 2: Recherche Binaire </b>

# %%
data = quickSort(data)
from time import perf_counter as now
time_start = now()

print(binary_search(data,surname))

time_end = now()
execution_time = time_end - time_start
print(execution_time)
# Out:
# True
# 0.00033970000000049794

# %% [markdown]
# # Graphe du temps d'execution

# %%
ys = []
for i in range(len(data)):
    dat = data[:i]
    l1 = []
    for element in dat:        
        time_start = now()
        algo1(data,element)
        time_end = now()
        execution_time = time_end - time_start
        l1.append(execution_time)
    if sum(l1) > 0:
        ys.append(len(l1)/sum(l1))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-df55ec44364f> in <module>
#       6         time_start = now()
#       7         algo1(data,element)
# ----> 8         time_end = now()
#       9         execution_time = time_end - time_start
#      10         l1.append(execution_time)
#
# KeyboardInterrupt:

# %%
ys
# Out:
# [0.01925889999984065,
#  0.0214773999996396,
#  0.017796199999793316,
#  0.01667659999930038,
#  0.01808600000003935,
#  0.016981600000690378,
#  0.016121599999678438,
#  0.016715499999918393,
#  0.015188099999249971,
#  0.01599869999972725,
#  0.017788599999221333,
#  0.016414800000347896,
#  0.014230499999939639,
#  0.014635000000453147,
#  0.015303900000617432,
#  0.016533099999833212,
#  0.017144999999800348,
#  0.02055930000005901,
#  0.0161908999998559,
#  0.019841600000290782,
#  0.016281899999739835,
#  0.014877500000693544,
#  0.015053000000079919,
#  0.016260500000498723,
#  0.0190005000004021,
#  0.015375699999822245,
#  0.016242499999862048,
#  0.015345900000284018,
#  0.015967600000294624,
#  0.015011699999377015,
#  0.017315099999905215,
#  0.014314100000774488,
#  0.01611349999984668,
#  0.01489190000029339,
#  0.02267989999927522,
#  0.01800069999990228,
#  0.017131900000094902,
#  0.016907799999898998,
#  0.015800299999682466,
#  0.016359400000510504,
#  0.0174646000004941,
#  0.01581649999934598,
#  0.015998799999579205,
#  0.016007999999601452,
#  0.016501699999935227,
#  0.016129800000271644,
#  0.01676729999962845,
#  0.021755700000539946,
#  0.022297399999843037,
#  0.018401999999696272,
#  0.01595069999984844,
#  0.014782799999920826,
#  0.016080299999885028,
#  0.015468100000362028,
#  0.017337199999929,
#  0.01570810000066558,
#  0.014379700000063167,
#  0.014792999999372114,
#  0.015618700000231911,
#  0.016323900000315916,
#  0.014966800000365765,
#  0.025647599999501836,
#  0.017916100000547885,
#  0.014398500000424974,
#  0.016323300000294694,
#  0.018342999999731546,
#  0.02263760000005277,
#  0.018081399999573478,
#  0.015687300000536197,
#  0.016138700000738027,
#  0.01623490000019956,
#  0.01935589999993681,
#  0.019544800000403484,
#  0.019593600000007427,
#  0.019007699999747274,
#  0.016969500000413973,
#  0.016583300000093004,
#  0.016099299999950745,
#  0.01547500000015134,
#  0.015585799999826122,
#  0.01635420000002341,
#  0.015695699999923818,
#  0.018451699999786797,
#  0.016382900000280642,
#  0.01582460000008723,
#  0.015668600000026345,
#  0.023852000000260887,
#  0.019972099999904458,
#  0.016860699999597273,
